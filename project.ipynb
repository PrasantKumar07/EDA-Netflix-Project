# %% [markdown]
# ## Netflix Dataset Project

# %% [markdown]
# "Analyze Netflix titles to gain insights into content trends, audience preferences, and market dynamics, and to inform data-driven decisions for content creation, acquisition, and marketing strategies."
#
# In simpler terms, the project's main goal is to:
#
# . Understand what types of content are popular on Netflix
#
# . Identify trends and patterns in audience preferences
#
# . Provide insights to inform content creation, acquisition, and marketing decisions
# By achieving this goal, the project aims to help Netflix improve its content strategy, enhance user experience, and drive business growth.
#
# Analyzing Netflix titles can be an important project for several reasons:
#
# 1. Understanding Content Trends: Insights into popular genres, directors, and release years can help identify trends in content consumption.
#
# 2. Audience Preferences: Analyzing ratings and viewer engagement can reveal audience preferences and help content creators tailor their content.
#
# 3. Market Research: Understanding what types of content are popular can inform market research and strategic decisions for content creation and acquisition.
#
# 4. Personalization: Analyzing user behavior and preferences can help improve content recommendations and personalization.
#
# 5. Competitive Analysis: Comparing Netflix's content offerings with competitors can provide insights into market gaps and opportunities.
#
# Some potential applications of this project include:
#
# Content creation and acquisition strategies
# Targeted marketing and promotion
# User experience optimization
# Competitive analysis and market research

# %% [markdown]
# ## How to load the Netflix dataset?

# %%
import pandas as pd
import numpy as np
df = pd.read_csv("C:\\Users\\HP\\Downloads\\netflix_titles.csv") 
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
print(df['cast'].nunique())
# Out:
# 7692

# %%
print(df['rating'].unique())
# Out:
# ['PG-13' 'TV-MA' 'PG' 'TV-14' 'TV-PG' 'TV-Y' 'TV-Y7' 'R' 'TV-G' 'G'
#  'NC-17' '74 min' '84 min' '66 min' 'NR' nan 'TV-Y7-FV' 'UR']

# %%
num_ratings = df['rating'].nunique()
# Out:
# Number of unique rating types: 17

# %%
# Optional: Show frequency of each rating type
print(df['rating'].value_counts())
# Out:
# rating
# TV-MA       3207
# TV-14       2160
# TV-PG        863
# R            799
# PG-13        490
# TV-Y7        334
# TV-Y         307
# PG           287
# TV-G         220
# NR            80
# G             41
# TV-Y7-FV       6
# NC-17          3
# UR             3
# 74 min         1
# 84 min         1
# 66 min         1
# Name: count, dtype: int64

# %% [markdown]
# ## How to check the number of rows and columns?

# %%
df.shape
# Out:
# (8807, 12)

# %% [markdown]
# ## Top view in Dataset

# %%
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %% [markdown]
# ## Top 15 view in Dataset

# %%
df.head(15)
# Out:
#    show_id     type                                title  \
# 0       s1    Movie                 Dick Johnson Is Dead
# 1       s2  TV Show                        Blood & Water
# 2       s3  TV Show                            Ganglands
# 3       s4  TV Show                Jailbirds New Orleans
# 4       s5  TV Show                         Kota Factory
# 5       s6  TV Show                        Midnight Mass
# 6       s7    Movie     My Little Pony: A New Generation
# 7       s8    Movie                              Sankofa
# 8       s9  TV Show        The Great British Baking Show
# 9      s10    Movie                         The Starling
# 10     s11  TV Show  Vendetta: Truth, Lies and The Mafia
# 11     s12  TV Show                     Bangkok Breaking
# 12     s13    Movie                         Je Suis Karl
# 13     s14    Movie     Confessions of an Invisible Girl
# 14     s15  TV Show      Crime Stories: India Detectives
#
#                          director  \
# ...

# %% [markdown]
# ## Similarly what if we want to see the last 20 rows ?

# %%
df.tail(20)
# Out:
#      show_id     type                          title                 director  \
# 8787   s8788    Movie      You Can’t Fight Christmas              Kenny Young
# 8788   s8789    Movie                   You Carry Me               Ivona Juka
# 8789   s8790    Movie            You Changed My Life      Cathy Garcia-Molina
# 8790   s8791    Movie  You Don't Mess with the Zohan             Dennis Dugan
# 8791   s8792    Movie                    Young Adult            Jason Reitman
# 8792   s8793    Movie                    Young Tiger                   Mu Chu
# 8793   s8794    Movie           Yours, Mine and Ours             Raja Gosnell
# 8794   s8795    Movie                         اشتباك             Mohamed Diab
# 8795   s8796  TV Show                Yu-Gi-Oh! Arc-V                      NaN
# 8796   s8797  TV Show                     Yunus Emre                      NaN
# 8797   s8798  TV Show                      Zak Storm                      NaN
# ...

# %% [markdown]
# ## How to get the column names and data types?

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %% [markdown]
# ## the basic statistics of numerical columns?

# %%
df.describe() ## apply STATICS
# Out:
#        release_year
# count   8807.000000
# mean    2014.180198
# std        8.819312
# min     1925.000000
# 25%     2013.000000
# 50%     2017.000000
# 75%     2019.000000
# max     2021.000000

# %% [markdown]
# ##  find missing/null values in the dataset?

# %%
df.isnull().sum()  ## check null values
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %% [markdown]
# ## Basic operations on columns
#
# Now what operations can we do using columns?
#
#
# Maybe add a column
#
# or delete a column
#
# or we can rename the column too

# %% [markdown]
# ## How can we get the names of all these cols ?

# %%
df.columns # using attribute `columns` of dataframe
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
df.keys # using method keys() of dataframe
# Out:
# <bound method NDFrame.keys of      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# ...

# %% [markdown]
# ## what is so "special" about this dictionary?
# It can take multiple keys

# %%
df[['title','release_year']].head()
# Out:
#                    title  release_year
# 0   Dick Johnson Is Dead          2020
# 1          Blood & Water          2021
# 2              Ganglands          2021
# 3  Jailbirds New Orleans          2021
# 4           Kota Factory          2021

# %% [markdown]
# ## How can we find the countries that have Netflix ?
#
#
# We can find the unique  country in Netflix
#
# How can we find unique values in a column?

# %%
df['country'].unique()
# Out:
# array(['United States', 'South Africa', nan, 'India',
#        'United States, Ghana, Burkina Faso, United Kingdom, Germany, Ethiopia',
#        'United Kingdom', 'Germany, Czech Republic', 'Mexico', 'Turkey',
#        'Australia', 'United States, India, France', 'Finland',
#        'China, Canada, United States',
#        'South Africa, United States, Japan', 'Nigeria', 'Japan',
#        'Spain, United States', 'France', 'Belgium',
#        'United Kingdom, United States', 'United States, United Kingdom',
#        'France, United States', 'South Korea', 'Spain',
#        'United States, Singapore', 'United Kingdom, Australia, France',
#        'United Kingdom, Australia, France, United States',
#        'United States, Canada', 'Germany, United States',
#        'South Africa, United States', 'United States, Mexico',
#        'United States, Italy, France, Japan',
#        'United States, Italy, Romania, United Kingdom',
#        'Australia, United States', 'Argentina, Venezuela',
# ...

# %%
df['Country'].str.split(',')
# Out:
# 0       [United States]
# 1        [South Africa]
# 2             [Unknown]
# 3             [Unknown]
# 4               [India]
#              ...
# 8802    [United States]
# 8803          [Unknown]
# 8804    [United States]
# 8805    [United States]
# 8806            [India]
# Name: Country, Length: 8807, dtype: object

# %% [markdown]
# ## Now what if you also want to check the count of each country in the dataframe?

# %%
df['country'].value_counts()
# Out:
# country
# United States                             2818
# India                                      972
# United Kingdom                             419
# Japan                                      245
# South Korea                                199
#                                           ...
# Romania, Bulgaria, Hungary                   1
# Uruguay, Guatemala                           1
# France, Senegal, Belgium                     1
# Mexico, United States, Spain, Colombia       1
# United Arab Emirates, Jordan                 1
# Name: count, Length: 748, dtype: int64

# %% [markdown]
# ## What if we want to change the name of a column ?
# We can rename the column by:
#
# passing the dictionary with old_name:new_name pair
#
# specifying axis=1

# %%
df.rename({"country":'Country','release_year': 'Release_year'}, axis=1)
df
##  not parmenent use parmanent ke liye inplace use karna padta h
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        Country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
df['country'] # before use in inplace then this time  not  change
# Out:
# 0       United States
# 1        South Africa
# 2                 NaN
# 3                 NaN
# 4               India
#             ...
# 8802    United States
# 8803              NaN
# 8804    United States
# 8805    United States
# 8806            India
# Name: Country, Length: 8807, dtype: object

# %% [markdown]
# ## Note
# rename has default value of axis=0
#
# If two columns have the same name, then df['column'] will display both columns

# %%
df.rename({"country":'Country','release_year': 'Release_year'}, axis=1, inplace=True)
df
# Out:
# 0       United States
# 1        South Africa
# 2                 NaN
# 3                 NaN
# 4               India
#             ...
# 8802    United States
# 8803              NaN
# 8804    United States
# 8805    United States
# 8806            India
# Name: Country, Length: 8807, dtype: object

# %% [markdown]
# ## Now lets try another way of accessing column vals

# %%
df.Country
# Out:
# 0       United States
# 1        South Africa
# 2                 NaN
# 3                 NaN
# 4               India
#             ...
# 8802    United States
# 8803              NaN
# 8804    United States
# 8805    United States
# 8806            India
# Name: Country, Length: 8807, dtype: object

# %% [markdown]
# ## What do you think could be the problems with using attribute style for accessing the columns?
# Problems such as
#       * if the column names are not strings
#
#             ~ Starting with number: E.g., 2nd
#
#             ~  Contains a space: E.g., Roll Number
#
#        * or if the column names conflict with methods of the DataFrame
#             ~ E.g. shape

# %% [markdown]
# Are all the columns in our data necessary?
#
# We already know the type in which each country lies
#
# So we don't need this column

# %% [markdown]
# ## How can we delete cols in pandas dataframe ?

# %%
df.drop('description', axis=1)
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        Country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %% [markdown]
# ## The drop function takes two parameters:
# The column name
#
#     . The axis
#
# By default the value of axis is 0
#
# An alternative to the above approach is using the "columns" parameter as we did in rename

# %%
df.drop(columns=['description'])
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        Country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %% [markdown]
# ## As you can see, column description is dropped
#
#
# Has the column permanently been deleted?

# %%
df.head ()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        Country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  Release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %% [markdown]
# NO, the column description is still there
#
# Do you see what's happening here?
#
# We only got a view of dataframe with column description dropped
#
# How can we permanently drop the column?
#
# We can either re-assign it
#
# df = df.drop('description', axis=1)
# OR
#
# We can set parameter inplace=True
#
# By default, inplace=False

# %%
df.drop('description', axis=1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[52], line 1
# ----> 1 df.drop('description', axis=1, inplace=True)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\frame.py:5258, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5110 def drop(
#    5111     self,
#    5112     labels: IndexLabel = None,
#    (...)
#    5119     errors: IgnoreRaise = "raise",
#    5120 ) -> DataFrame | None:
#    5121     """
#    5122     Drop specified labels from rows or columns.
#    5123
#    (...)
#    5256             weight  1.0     0.8
#    5257     """
# -> 5258     return super().drop(
#    5259         labels=labels,
#    5260         axis=axis,
#    5261         index=index,
#    5262         columns=columns,
#    5263         level=level,
#    5264         inplace=inplace,
#    5265         errors=errors,
#    5266     )
#
# ...

# %%
df.head() #we print the head to check
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        Country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  Release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %% [markdown]
# ## Now we can see the column description is permanently dropped

# %% [markdown]
# ##  Now similarly, what if we want to create a new column?
#
# We can either
#
#      . use values from existing columns
#
# OR
#
#      .  create our own values
#
# How to create a column using values from an existing column?

# %%
df["Release_year+7"] = df["Release_year"] + 7
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        Country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  Release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %% [markdown]
# ## As we see, a new column year+7 is created from the column year
# ## We can also use values from two columns to form a new column
# ## Which two columns can we use to create a new column gdp ?

# %%
df['Release']=df['Release_year'] * df['rating']
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        Country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  Release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %% [markdown]
# ## As you can see
#
#   . An additional column has been created
#
#   . Values in this column are product of respective values in gdp_cap and population
#
# What other operations we can use?
#
# Subtraction, Addition, etc.
# ## How can we create a new column from our own values?
#
#   . We can create a list
#
# OR
#
#
#    . We can create a Pandas Series from a list/numpy array for our new column
# Country

# %%
df["Own"] = [i for i in range(8807)] # count of these values should be correct
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        Country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %% [markdown]
# ## Now that we know how to create new cols lets see some basic ops on rows
# ## Before that lets drop the newly created cols

# %%
df.drop(columns=["Release_year+7"], inplace=True, errors='ignore')
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        Country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
df.drop(columns=["Release_year+7","Own","Release"], inplace=True, errors='ignore')
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        Country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %% [markdown]
# ## Working with Rows
#
# Just like columns, do rows also have labels?
#
# YES
#
# Notice the indexes in bold against each row    ,
# Lets see how can we access these indexes

# %%
df.index.values
# Out:
# array([   0,    1,    2, ..., 8804, 8805, 8806], dtype=int64)

# %% [markdown]
# ## Can we change row labels (like we did for columns)?
#
# What if we want to start indexing from 1 (instead of 0)?

# %%
df.index = list(range(1, df.shape[0]+1)) # create a list of indexes of same length
df
# Out:
#      show_id     type                  title         director  \
# 1         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 2         s2  TV Show          Blood & Water              NaN
# 3         s3  TV Show              Ganglands  Julien Leclercq
# 4         s4  TV Show  Jailbirds New Orleans              NaN
# 5         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8803   s8803    Movie                 Zodiac    David Fincher
# 8804   s8804  TV Show            Zombie Dumb              NaN
# 8805   s8805    Movie             Zombieland  Ruben Fleischer
# 8806   s8806    Movie                   Zoom     Peter Hewitt
# 8807   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        Country  \
# 1                                                   NaN  United States
# 2     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %% [markdown]
# ## Explicit and Implicit Indices
#
# What are these row labels/indices exactly ?
#
#    . They can be called identifiers of a particular row
#    .Specifically known as explicit indices
#
# ## Additionally, can series/dataframes can also use python style indexing?
#
# YES
#
# The python style indices are known as implicit indices
#
# ## How can we access explicit index of a particular row?
#
#   . Using df.index[]
#   . Takes impicit index of row to give its explicit index

# %%
df.index[1] #Implicit index 1 gave explicit index 2
# Out:
# 2

# %% [markdown]
# ## But why not use just implicit indexing ?
#
# Explicit indices can be changed to any value of any datatype
#
# Eg: Explicit Index of 1st row can be changed to First
# Or, something like a floating point value, say 1.0

# %%
df.index = np.arange(1, df.shape[0]+1, dtype='float')
df
# Out:
#        show_id     type                  title         director  \
# 1.0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 2.0         s2  TV Show          Blood & Water              NaN
# 3.0         s3  TV Show              Ganglands  Julien Leclercq
# 4.0         s4  TV Show  Jailbirds New Orleans              NaN
# 5.0         s5  TV Show           Kota Factory              NaN
# ...        ...      ...                    ...              ...
# 8803.0   s8803    Movie                 Zodiac    David Fincher
# 8804.0   s8804  TV Show            Zombie Dumb              NaN
# 8805.0   s8805    Movie             Zombieland  Ruben Fleischer
# 8806.0   s8806    Movie                   Zoom     Peter Hewitt
# 8807.0   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                      cast        Country  \
# 1.0                                                   NaN  United States
# ...

# %% [markdown]
#   As we can see, the indices are floating point values now

# %%
sample = df.head()
sample
# Out:
#     show_id     type                  title         director  \
# 1.0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 2.0      s2  TV Show          Blood & Water              NaN
# 3.0      s3  TV Show              Ganglands  Julien Leclercq
# 4.0      s4  TV Show  Jailbirds New Orleans              NaN
# 5.0      s5  TV Show           Kota Factory              NaN
#
#                                                   cast        Country  \
# 1.0                                                NaN  United States
# 2.0  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 3.0  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 4.0                                                NaN            NaN
# 5.0  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#              date_added  Release_year rating   duration  \
# 1.0  September 25, 2021          2020  PG-13     90 min
# 2.0  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %% [markdown]
# ## Now what if we want to use string indices?

# %%
sample.index = ['a', 'b', 'c', 'd', 'e']
sample
# Out:
#   show_id     type                  title         director  \
# a      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# b      s2  TV Show          Blood & Water              NaN
# c      s3  TV Show              Ganglands  Julien Leclercq
# d      s4  TV Show  Jailbirds New Orleans              NaN
# e      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        Country  \
# a                                                NaN  United States
# b  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# c  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# d                                                NaN            NaN
# e  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  Release_year rating   duration  \
# a  September 25, 2021          2020  PG-13     90 min
# b  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %% [markdown]
# ## loc and iloc
# 1. loc

# %% [markdown]
# Allows indexing and slicing that always references the explicit index

# %%
df.loc[1]
# Out:
# show_id                           s1
# type                           Movie
# title           Dick Johnson Is Dead
# director             Kirsten Johnson
# cast                             NaN
# Country                United States
# date_added        September 25, 2021
# Release_year                    2020
# rating                         PG-13
# duration                      90 min
# listed_in              Documentaries
# Name: 1.0, dtype: object

# %%
df.loc[1:3]
# Out:
#     show_id     type                 title         director  \
# 1.0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 2.0      s2  TV Show         Blood & Water              NaN
# 3.0      s3  TV Show             Ganglands  Julien Leclercq
#
#                                                   cast        Country  \
# 1.0                                                NaN  United States
# 2.0  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 3.0  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
#
#              date_added  Release_year rating   duration  \
# 1.0  September 25, 2021          2020  PG-13     90 min
# 2.0  September 24, 2021          2021  TV-MA  2 Seasons
# 3.0  September 24, 2021          2021  TV-MA   1 Season
#
#                                              listed_in
# 1.0                                      Documentaries
# 2.0    International TV Shows, TV Dramas, TV Mysteries
# ...

# %% [markdown]
# Now as previous Dataset index

# %%
df.index = np.arange(0, df.shape[0]+0, dtype='int')
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        Country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %% [markdown]
# ## 2. iloc
#
# Allows indexing and slicing that always references the implicit Python-style index

# %%
df.iloc[1]
# Out:
# show_id                                                        s2
# type                                                      TV Show
# title                                               Blood & Water
# director                                                      NaN
# cast            Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...
# Country                                              South Africa
# date_added                                     September 24, 2021
# Release_year                                                 2021
# rating                                                      TV-MA
# duration                                                2 Seasons
# listed_in         International TV Shows, TV Dramas, TV Mysteries
# Name: 1, dtype: object

# %% [markdown]
# Now will iloc also consider the range inclusive?

# %%
df.iloc[0:2]
# Out:
#   show_id     type                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water              NaN
#
#                                                 cast        Country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
#
#            date_added  Release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                          listed_in
# 0                                    Documentaries
# 1  International TV Shows, TV Dramas, TV Mysteries

# %% [markdown]
# ## What if we want to access multiple non-consecutive rows at same time ?
# For eg: rows 1, 10, 100

# %%
df.iloc[[1,10,100]]
# Out:
#     show_id     type                                title director  \
# 1        s2  TV Show                        Blood & Water      NaN
# 10      s11  TV Show  Vendetta: Truth, Lies and The Mafia      NaN
# 100    s101  TV Show              Tobot Galaxy Detectives      NaN
#
#                                                   cast       Country  \
# 1    Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...  South Africa
# 10                                                 NaN           NaN
# 100  Austin Abell, Travis Turner, Cole Howard, Anna...           NaN
#
#              date_added  Release_year rating   duration  \
# 1    September 24, 2021          2021  TV-MA  2 Seasons
# 10   September 24, 2021          2021  TV-MA   1 Season
# 100   September 7, 2021          2019  TV-Y7  2 Seasons
#
#                                              listed_in
# 1      International TV Shows, TV Dramas, TV Mysteries
# 10   Crime TV Shows, Docuseries, International TV S...
# ...

# %% [markdown]
# ## What about negative index?
#
# Which would work between iloc and loc ?

# %%
df.iloc[-1]
# Works and gives last row in dataframe
# Out:
# show_id                                                     s8807
# type                                                        Movie
# title                                                      Zubaan
# director                                              Mozez Singh
# cast            Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...
# Country                                                     India
# date_added                                          March 2, 2019
# Release_year                                                 2015
# rating                                                      TV-14
# duration                                                  111 min
# listed_in          Dramas, International Movies, Music & Musicals
# Name: 8806, dtype: object

# %%
df.loc[-1]
# Does NOT work

# %% [markdown]
# So, why did iloc[-1] worked, but loc[-1] didn't?
#
#
#     . Because iloc works with positional indices, while loc with assigned labels
#
#     . [-1] here points to the row at last position in iloc

# %% [markdown]
# ## How to find missing/null values in the dataset?

# %%
df.isnull().sum()
# Out:
# show_id           0
# type              0
# title             0
# director          0
# cast            825
# Country           0
# date_added       10
# Release_year      0
# rating            4
# duration          3
# listed_in         0
# dtype: int64

# %% [markdown]
# ## How to remove duplicate rows from the dataset?

# %%
df.drop_duplicates(inplace=True)
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water      No Director
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans      No Director
# 4         s5  TV Show           Kota Factory      No Director
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb      No Director
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        Country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
df.drop_duplicates(subset=['Country'],keep='first')
# Out:
#      show_id     type                 title         director  \
# 0         s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show         Blood & Water              NaN
# 2         s3  TV Show             Ganglands  Julien Leclercq
# 4         s5  TV Show          Kota Factory              NaN
# 7         s8    Movie               Sankofa     Haile Gerima
# ...      ...      ...                   ...              ...
# 8784   s8785    Movie  Yoko and His Friends              NaN
# 8788   s8789    Movie          You Carry Me       Ivona Juka
# 8795   s8796  TV Show       Yu-Gi-Oh! Arc-V              NaN
# 8797   s8798  TV Show             Zak Storm              NaN
# 8801   s8802    Movie               Zinzana  Majid Al Ansari
#
#                                                    cast  \
# 0                                                   NaN
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...
# 2     Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...
# ...

# %% [markdown]
# ## How to handle missing values in the dataset?

# %%
df['director'].fillna('No Director', inplace=True)
df['Country'].fillna('Unknown', inplace=True)
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water      No Director
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans      No Director
# 4         s5  TV Show           Kota Factory      No Director
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb      No Director
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        Country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %% [markdown]
# ## We can mention ranges using column labels as well in loc

# %%
df.loc[1:5, 'title':'duration']
# Out:
#                    title         director  \
# 1          Blood & Water              NaN
# 2              Ganglands  Julien Leclercq
# 3  Jailbirds New Orleans              NaN
# 4           Kota Factory              NaN
# 5          Midnight Mass    Mike Flanagan
#
#                                                 cast       Country  \
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...  South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...           NaN
# 3                                                NaN           NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...         India
# 5  Kate Siegel, Zach Gilford, Hamish Linklater, H...           NaN
#
#            date_added  Release_year rating   duration
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# 2  September 24, 2021          2021  TV-MA   1 Season
# 3  September 24, 2021          2021  TV-MA   1 Season
# 4  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %% [markdown]
# ## Sorting
#
#  If you notice, life_exp col is not sorted
#
# How can we perform sorting in pandas ?

# %%
df.sort_values(['duration'])
# Out:
#      show_id     type                                 title      director  \
# 8216   s8217  TV Show                        The Bomb Squad           NaN
# 5392   s5393  TV Show         Barbie Life in the Dreamhouse           NaN
# 3794   s3795  TV Show                     Historical Roasts           NaN
# 1593   s1594  TV Show                      Kings of Jo'Burg           NaN
# 5393   s5394  TV Show                              Breakout           NaN
# ...      ...      ...                                   ...           ...
# 5976   s5977    Movie           Çok Filim Hareketler Bunlar  Ozan Açıktan
# 4401   s4402    Movie         All's Well, End's Well (2009)   Vincent Kok
# 5541   s5542    Movie                       Louis C.K. 2017    Louis C.K.
# 5794   s5795    Movie                 Louis C.K.: Hilarious    Louis C.K.
# 5813   s5814    Movie  Louis C.K.: Live at the Comedy Store    Louis C.K.
#
#                                                    cast  \
# ...

# %% [markdown]
# Which directors have the most content on Netflix?

# %%
df['director'].value_counts().head(10)
# Out:
# director
# Rajiv Chilaka             19
# Raúl Campos, Jan Suter    18
# Marcus Raboy              16
# Suhas Kadav               16
# Jay Karas                 14
# Cathy Garcia-Molina       13
# Martin Scorsese           12
# Youssef Chahine           12
# Jay Chapman               12
# Steven Spielberg          11
# Name: count, dtype: int64

# %%
df['director'].value_counts()
# Out:
# director
# Rajiv Chilaka                     19
# Raúl Campos, Jan Suter            18
# Marcus Raboy                      16
# Suhas Kadav                       16
# Jay Karas                         14
#                                   ..
# Raymie Muzquiz, Stu Livingston     1
# Joe Menendez                       1
# Eric Bross                         1
# Will Eisenberg                     1
# Mozez Singh                        1
# Name: count, Length: 4528, dtype: int64

# %% [markdown]
#  Which country has the most TV Shows on Netflix?

# %%
df[df['type'] == 'TV Show']['Country'].value_counts().head(10)
# Out:
# Country
# United States     760
# United Kingdom    213
# Japan             169
# South Korea       158
# India              79
# Taiwan             68
# Canada             59
# France             49
# Australia          48
# Spain              48
# Name: count, dtype: int64

# %% [markdown]
# ## How are ratings distributed among content types?

# %%
sns.countplot(data=df, x='rating', hue='type')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# Which countries have the most Netflix content?

# %%
df['Country'].value_counts().head(10)
# Out:
# Country
# United States     2818
# India              972
# United Kingdom     419
# Japan              245
# South Korea        199
# Canada             181
# Spain              145
# France             124
# Mexico             110
# Egypt              106
# Name: count, dtype: int64

# %% [markdown]
# Which ratings are most common on Netflix?

# %%
df['rating'].value_counts()
# Out:
# rating
# TV-MA       3207
# TV-14       2160
# TV-PG        863
# R            799
# PG-13        490
# TV-Y7        334
# TV-Y         307
# PG           287
# TV-G         220
# NR            80
# G             41
# TV-Y7-FV       6
# NC-17          3
# UR             3
# 74 min         1
# 84 min         1
# 66 min         1
# Name: count, dtype: int64

# %% [markdown]
# ## Univariate Analysis
# What are the counts of different content types (Movie or TV Show)?

# %%
df['type'].value_counts()
# Out:
# type
# Movie      6131
# TV Show    2676
# Name: count, dtype: int64

# %% [markdown]
# ## What is the distribution of content durations? (Movies vs. TV Shows)

# %%
df['duration'].value_counts().head(10)
# Out:
# duration
# 1 Season     1793
# 2 Seasons     425
# 3 Seasons     199
# 90 min        152
# 94 min        146
# 97 min        146
# 93 min        146
# 91 min        144
# 95 min        137
# 96 min        130
# Name: count, dtype: int64

# %%
df['duration'].value_counts()
# Out:
# duration
# 1 Season     1793
# 2 Seasons     425
# 3 Seasons     199
# 90 min        152
# 94 min        146
#              ...
# 16 min          1
# 186 min         1
# 193 min         1
# 189 min         1
# 191 min         1
# Name: count, Length: 220, dtype: int64

# %% [markdown]
# ## Multivariate Analysis
# Which countries produce more Movies vs. TV Shows?

# %%
df.groupby(['Country', 'type']).size().unstack().fillna(0).sort_values('Movie', ascending=False).head(10)
# Out:
# type             Movie  TV Show
# Country
# United States   2058.0    760.0
# India            893.0     79.0
# United Kingdom   206.0    213.0
# Canada           122.0     59.0
# Spain             97.0     48.0
# Egypt             92.0     14.0
# Nigeria           86.0      9.0
# Indonesia         77.0      2.0
# Japan             76.0    169.0
# Turkey            76.0     29.0

# %% [markdown]
# ## groupby

# %% [markdown]
# ## How many shows are available in each country?

# %%
df.groupby('Country').size().sort_values(ascending=False).head(10)
# Out:
# Country
# United States     2818
# India              972
# Unknown            831
# United Kingdom     419
# Japan              245
# South Korea        199
# Canada             181
# Spain              145
# France             124
# Mexico             110
# dtype: int64

# %% [markdown]
# ## What is the distribution of Movies and TV Shows in each country?

# %%
df.groupby(['Country', 'type']).size().unstack().fillna(0)
# Out:
# type                                                Movie  TV Show
# Country
# , France, Algeria                                     1.0      0.0
# , South Korea                                         0.0      1.0
# Argentina                                            38.0     18.0
# Argentina, Brazil, France, Poland, Germany, Den...    1.0      0.0
# Argentina, Chile                                      2.0      0.0
# ...                                                   ...      ...
# Venezuela                                             1.0      0.0
# Venezuela, Colombia                                   1.0      0.0
# Vietnam                                               7.0      0.0
# West Germany                                          1.0      0.0
# Zimbabwe                                              1.0      0.0
#
# [749 rows x 2 columns]

# %% [markdown]
# ## GroupBy with Multiple Columns and Conditions
#     . In which year did each country add the most content?

# %%
df.groupby(['Country', 'Release_year']).size().groupby('Country').idxmax()
# Out:
# Country
# , France, Algeria                                                              (, France, Algeria, 2014)
# , South Korea                                                                      (, South Korea, 2021)
# Argentina                                                                              (Argentina, 2020)
# Argentina, Brazil, France, Poland, Germany, Denmark    (Argentina, Brazil, France, Poland, Germany, D...
# Argentina, Chile                                                                (Argentina, Chile, 2006)
#                                                                              ...
# Venezuela                                                                              (Venezuela, 2017)
# Venezuela, Colombia                                                          (Venezuela, Colombia, 2007)
# Vietnam                                                                                  (Vietnam, 2019)
# ...

# %% [markdown]
# ## How many Movies and TV Shows does each director have?

# %%
df.groupby(['director', 'type']).size().sort_values(ascending=False).head(10)
# Out:
# director                type
# No Director             TV Show    2446
#                         Movie       188
# Rajiv Chilaka           Movie        19
# Raúl Campos, Jan Suter  Movie        18
# Suhas Kadav             Movie        16
# Marcus Raboy            Movie        15
# Jay Karas               Movie        14
# Cathy Garcia-Molina     Movie        13
# Jay Chapman             Movie        12
# Martin Scorsese         Movie        12
# dtype: int64

# %% [markdown]
# ## How many contents were released each year per country? (Trend Analysis)

# %%
df.groupby(['Country', 'Release_year']).size().unstack(fill_value=0).head(1000)
# Out:
# Release_year                                        1925  1942  1943  1944  \
# Country
# , France, Algeria                                      0     0     0     0
# , South Korea                                          0     0     0     0
# Argentina                                              0     0     0     0
# Argentina, Brazil, France, Poland, Germany, Den...     0     0     0     0
# Argentina, Chile                                       0     0     0     0
# ...                                                  ...   ...   ...   ...
# Venezuela                                              0     0     0     0
# Venezuela, Colombia                                    0     0     0     0
# Vietnam                                                0     0     0     0
# West Germany                                           0     0     0     0
# Zimbabwe                                               0     0     0     0
#
# ...

# %% [markdown]
# What is the distribution of content by each rating type (like TV-MA, PG)?

# %%
df.groupby('rating').size().sort_values(ascending=False)
# Out:
# rating
# TV-MA       3207
# TV-14       2160
# TV-PG        863
# R            799
# PG-13        490
# TV-Y7        334
# TV-Y         307
# PG           287
# TV-G         220
# NR            80
# G             41
# TV-Y7-FV       6
# UR             3
# NC-17          3
# 74 min         1
# 84 min         1
# 66 min         1
# dtype: int64

# %% [markdown]
# ## What is the most popular genre for each director?

# %%
df.groupby(['director', 'listed_in']).size().sort_values(ascending=False).head(15)
# Out:
# director     listed_in
# No Director  Kids' TV                                                             214
#              International TV Shows, TV Dramas                                    113
#              Reality TV                                                            94
#              Crime TV Shows, International TV Shows, TV Dramas                     92
#              Kids' TV, TV Comedies                                                 91
#              International TV Shows, Romantic TV Shows, TV Dramas                  88
#              Anime Series, International TV Shows                                  83
#              International TV Shows, Romantic TV Shows, TV Comedies                82
#              Docuseries                                                            68
#              TV Comedies                                                           67
#              International TV Shows, Korean TV Shows, Romantic TV Shows            60
# ...

# %% [markdown]
# ## Which country contributed the most content to each genre?

# %%
df.groupby(['Country', 'listed_in']).size().sort_values(ascending=False).head(20)
# Out:
# Country        listed_in
# United States  Documentaries                                                 249
#                Stand-Up Comedy                                               209
# India          Comedies, Dramas, International Movies                        120
#                Dramas, International Movies                                  118
#                Dramas, Independent Movies, International Movies              108
# United States  Children & Family Movies, Comedies                             90
#                Dramas                                                         88
#                Comedies                                                       84
#                Children & Family Movies                                       80
#                Kids' TV                                                       77
# Japan          Anime Series, International TV Shows                           75
# ...

# %%
df['type'].value_counts()
# OR
df.groupby('type').size()
# Out:
# type
# Movie      6131
# TV Show    2676
# dtype: int64

# %%
df.groupby('type').count()
# Out:
#          show_id  title  director  cast  Country  date_added  Release_year  \
# type
# Movie       6131   6131      6131  5656     6131        6131          6131
# TV Show     2676   2676      2676  2326     2676        2666          2676
#
#          rating  duration  listed_in
# type
# Movie      6129      6128       6131
# TV Show    2674      2676       2676

# %% [markdown]
# ## countplot()

# %%
sns.countplot(data=df, x='type', palette='Set2') # palette is color design
# Out:
# <Axes: xlabel='type', ylabel='count'>

# %% [markdown]
# use countplot()

# %%
sns.countplot(data=df, x='type', hue='Country', palette='bright') 

## large amount of Answer this code
# use hue = This gives different categories different colors, making it easier to identify patterns

# %%
import seaborn as sns
import matplotlib.pyplot as plt

df.groupby(['Release_year', 'type']).size().unstack().plot(kind='line', figsize=(12,6))
plt.title('Year-wise Netflix Content Growth')
plt.ylabel('Number of Contents')
plt.show()

# %% [markdown]
# What is the yearly distribution of Movies and TV Shows on Netflix?

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(12,6))
sns.countplot(data=df, x='Release_year', hue='type', order=sorted(df['Release_year'].unique()))
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ## How are ratings distributed among content types?

# %%
sns.countplot(data=df, x='rating', hue='type')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## What is the year-wise growth trend of Movies and TV Shows on Netflix?

# %%
df.groupby(['Release_year', 'type']).size().unstack(fill_value=0).plot(kind='line', figsize=(12,6))
# Out:
# <Axes: xlabel='Release_year'>

# %% [markdown]
# ## Example Final Visualization: Pie Chart

# %%
df['type'].value_counts().plot.pie(autopct='%1.1f%%', startangle=90, colors=['lightblue', 'orange'])
plt.title('Distribution of Content Types')
plt.show()

# %% [markdown]
# ## Content by Country: Bar Plot

# %%
df['Country_simple'] = df['Country'].str.split(',').str[0]  
top_Countries = df['Country_simple'].value_counts().head(10)
plt.figure(figsize=(10,5))
sns.barplot(x=top_Countries.values, y=top_Countries.index, palette='flare')
plt.title('Top 10 Countries Producing Netflix Content')
plt.xlabel('Number of Titles')
plt.ylabel('Country')
plt.show()

# %%
# Import required libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# Load dataset
df = pd.read_csv('netflix_titles.csv')

# Data Cleaning
df['country'].fillna('Unknown', inplace=True)
df['rating'].fillna('Unknown', inplace=True)
df['release_year'].fillna(0, inplace=True)
df['listed_in'] = df['listed_in'].str.split(', ')
genres = df.explode('listed_in')

# Plot 1: Content Type Distribution (Matplotlib)
plt.figure(figsize=(6, 6))
type_counts = df['type'].value_counts()
plt.pie(type_counts, labels=type_counts.index, autopct='%1.1f%%', colors=['#ff9999','#66b3ff'])
plt.title('Distribution of Content Type')
plt.show()

# Plot 2: Top 10 Countries by Number of Titles (Seaborn)
plt.figure(figsize=(10, 6))
top_countries = df['country'].value_counts().head(10)
sns.barplot(x=top_countries.values, y=top_countries.index, palette='viridis')
plt.title('Top 10 Countries by Number of Titles')
plt.xlabel('Number of Titles')
plt.ylabel('Country')
plt.show()

# Plot 3: Rating Distribution (Seaborn)
plt.figure(figsize=(12, 6))
sns.countplot(data=df, x='rating', order=df['rating'].value_counts().index, palette='coolwarm')
plt.title('Distribution of Ratings on Netflix')
plt.xticks(rotation=45)
plt.show()

# Plot 4: Top 10 Genres (Seaborn)
plt.figure(figsize=(10, 6))
top_genres = genres['listed_in'].value_counts().reset_index().head(10)
top_genres.columns = ['Genre', 'Count']
sns.barplot(data=top_genres, x='Count', y='Genre', palette='magma')
plt.title('Top 10 Genres on Netflix')
plt.xlabel('Number of Titles')
plt.ylabel('Genre')
plt.show()

# Plot 5: Content Release Trend Over Years (Plotly)
release_trend = df['release_year'].value_counts().reset_index()
release_trend.columns = ['Year', 'Count']
release_trend = release_trend.sort_values('Year')
fig = px.line(release_trend, x='Year', y='Count', title='Content Release Trend Over Years')
fig.show()

# %%
# Import required libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# Load dataset
df = pd.read_csv('netflix_titles.csv')

# Data Cleaning
df['country'].fillna('Unknown', inplace=True)
df['rating'].fillna('Unknown', inplace=True)
df['release_year'].fillna(0, inplace=True)
df['listed_in'] = df['listed_in'].str.split(', ')
genres = df.explode('listed_in')

# Create a single frame with 2x2 grid
plt.figure(figsize=(20, 15))

# Plot 1: Content Type Distribution (Pie Chart)
plt.subplot(2, 2, 1)
type_counts = df['type'].value_counts()
plt.pie(type_counts, labels=type_counts.index, autopct='%1.1f%%', colors=['#ff9999','#66b3ff'])
plt.title('Distribution of Content Type')

# Plot 2: Top 10 Countries (Bar Plot)
plt.subplot(2, 2, 2)
top_countries = df['country'].value_counts().head(10)
sns.barplot(x=top_countries.values, y=top_countries.index, palette='viridis')
plt.title('Top 10 Countries by Number of Titles')
plt.xlabel('Number of Titles')
plt.ylabel('Country')

# Plot 3: Rating Distribution (Count Plot)
plt.subplot(2, 2, 3)
sns.countplot(data=df, x='rating', order=df['rating'].value_counts().index, palette='coolwarm')
plt.title('Distribution of Ratings on Netflix')
plt.xlabel('Rating')
plt.ylabel('Count')
plt.xticks(rotation=45)

# Plot 4: Top Genres (Bar Plot)
plt.subplot(2, 2, 4)
top_genres = genres['listed_in'].value_counts().reset_index().head(10)
top_genres.columns = ['Genre', 'Count']
sns.barplot(data=top_genres, x='Count', y='Genre', palette='magma')
plt.title('Top 10 Genres on Netflix')
plt.xlabel('Number of Titles')
plt.ylabel('Genre')

# Adjust layout
plt.tight_layout()
plt.show()

# Plot 5: Release Trend (Plotly - Interactive)
release_trend = df['release_year'].value_counts().reset_index()
release_trend.columns = ['Year', 'Count']
release_trend = release_trend.sort_values('Year')

fig = px.line(release_trend, x='Year', y='Count', title='Content Release Trend Over Years')
fig.show()

# %%
netflix_titles = pd.read_csv('netflix_titles.csv')

genres = netflix_titles['listed_in'].str.split(',').explode()
genres
# Out:
# 0                  Documentaries
# 1         International TV Shows
# 1                      TV Dramas
# 1                   TV Mysteries
# 2                 Crime TV Shows
#                   ...
# 8805    Children & Family Movies
# 8805                    Comedies
# 8806                      Dramas
# 8806        International Movies
# 8806            Music & Musicals
# Name: listed_in, Length: 19323, dtype: object

# %%
# Import required libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load dataset
netflix_titles = pd.read_csv('netflix_titles.csv')

# Extract and separate genres
genres = netflix_titles['listed_in'].str.split(',').explode()

# Remove extra spaces
genres = genres.str.strip()

# Calculate frequency of each genre
genre_counts = genres.value_counts()

# Display top 10 genres
print("Top 10 Most Common Genres:")
print(genre_counts.head(10))

# Plotting genre-wise bar plot
plt.figure(figsize=(12, 6))
sns.barplot(x=genre_counts.index[:10], y=genre_counts.values[:10], palette='viridis')

plt.title('Top 10 Most Common Netflix Genres')
plt.xlabel('Genres')
plt.ylabel('Number of Titles')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)

plt.show()
# Out:
# Top 10 Most Common Genres:
# listed_in
# International Movies        2752
# Dramas                      2427
# Comedies                    1674
# International TV Shows      1351
# Documentaries                869
# Action & Adventure           859
# TV Dramas                    763
# Independent Movies           756
# Children & Family Movies     641
# Romantic Movies              616
# Name: count, dtype: int64

# %%
# Group by director and genre, count occurrences, then reset index
#director_genre_counts = df.groupby(['director', 'listed_in']).size().reset_index(name='count')

# Find the most popular genre for each director (max count per director)
#most_popular_genre_per_director = (
 #   director_genre_counts
  #  .sort_values('count', ascending=False)
   # .drop_duplicates('director')  # Keep only the highest count per director
    #.sort_values('count', ascending=False)
#)

# Display the results (director name + their most popular genre)
print(most_popular_genre_per_director[['director', 'listed_in', 'count']])
# Out:
#                              director  \
# 4130           Raúl Campos, Jan Suter
# 4061                    Rajiv Chilaka
# 3088                     Marcus Raboy
# 2119                        Jay Karas
# 2115                      Jay Chapman
# ...                               ...
# 5288                     Vitor Brandt
# 5298                  Vrinda Samartha
# 5297               Vondie Curtis-Hall
# 5296  Vonda Harrell, Daniel Camenisch
# 1901                      Hugo Stuven
#
#                                               listed_in  count
# 4130                                    Stand-Up Comedy     18
# 4061                           Children & Family Movies     18
# 3088                                    Stand-Up Comedy     15
# 2119                                    Stand-Up Comedy     13
# 2115                                    Stand-Up Comedy     11
# ...                                                 ...    ...
# ...

# %%
#print('most_popular_genre_per_director',[['director', 'listed_in', 'count']])
# Group by director and genre, count occurrences, then reset index
director_genre_counts = df.groupby(['director', 'listed_in']).size().reset_index(name='count')
print(director_genre_counts)
# Out:
#                  director                                          listed_in  \
# 0             A. L. Vijay             Comedies, Dramas, International Movies
# 1             A. L. Vijay   Comedies, International Movies, Sci-Fi & Fantasy
# 2            A. Raajdheep                       Dramas, International Movies
# 3               A. Salaam  Action & Adventure, International Movies, Musi...
# 4         A.R. Murugadoss   Action & Adventure, Dramas, International Movies
# ...                   ...                                                ...
# 5476  Óskar Thór Axelsson                Horror Movies, International Movies
# 5477     Ömer Faruk Sorak  Action & Adventure, Comedies, International Mo...
# 5478     Ömer Faruk Sorak      Dramas, International Movies, Romantic Movies
# 5479         Şenol Sönmez             Comedies, Dramas, International Movies
# 5480         Şenol Sönmez    Comedies, International Movies, Romantic Movies
#
#       count
# 0         1
# 1         1
# ...
